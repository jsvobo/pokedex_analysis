# %%
import pandas as pd
import numpy as np

pokemon_df = pd.read_csv('data/pokemon.csv', sep="\t", engine="python", encoding="utf-8")
print(pokemon_df.head())
# Out:
#    national_number gen english_name japanese_name primary_type secondary_type  \
# 0                1   I    Bulbasaur   Fushigidane        grass         poison
# 1                2   I      Ivysaur    Fushigisou        grass         poison
# 2                3   I     Venusaur   Fushigibana        grass         poison
# 3                4   I   Charmander      Hitokage         fire            NaN
# 4                5   I   Charmeleon       Lizardo         fire            NaN
#
#    classification percent_male percent_female  height_m  ...  evochain_1  \
# 0    Seed Pokémon        88.14          11.86       0.7  ...      Level
# 1    Seed Pokémon        88.14          11.86       1.0  ...      Level
# 2    Seed Pokémon        88.14          11.86       2.0  ...      Level
# 3  Lizard Pokémon        88.14          11.86       0.6  ...      Level
# 4   Flame Pokémon        88.14          11.86       1.1  ...      Level
#
#    evochain_2  evochain_3  evochain_4  evochain_5  evochain_6  \
# 0     Ivysaur      Level     Venusaur         NaN         NaN
# 1     Ivysaur      Level     Venusaur         NaN         NaN
# 2     Ivysaur      Level     Venusaur         NaN         NaN
# 3  Charmeleon      Level    Charizard         NaN         NaN
# 4  Charmeleon      Level    Charizard         NaN         NaN
#
#             gigantamax  mega_evolution  mega_evolution_alt  \
# 0                  NaN             NaN                 NaN
# 1                  NaN             NaN                 NaN
# 2  Gigantamax Venusaur   Mega Venusaur                 NaN
# 3                  NaN             NaN                 NaN
# 4                  NaN             NaN                 NaN
#
#                                          description
# 0  There is a plant seed on its back right from t...
# 1  When the bulb on its back grows large, it appe...
# 2  Its plant blooms when it is absorbing solar en...
# 3  It has a preference for hot things. When it ra...
# 4  It has a barbaric nature. In battle, it whips ...
#
# [5 rows x 55 columns]

# %%
print(pokemon_df.columns)
pokemon_df = pokemon_df.set_index('national_number')
pokemon_df = pokemon_df.drop(columns=[
    'english_name', 'japanese_name', 'description',
    'abilities_0', 'abilities_1', 'abilities_2', 'abilities_hidden',
    'evochain_0', 'evochain_1', 'evochain_2', 'evochain_3', 'evochain_4', 'evochain_5', 'evochain_6'
])
print(pokemon_df.columns)
# Out:
# Index(['national_number', 'gen', 'english_name', 'japanese_name',
#        'primary_type', 'secondary_type', 'classification', 'percent_male',
#        'percent_female', 'height_m', 'weight_kg', 'capture_rate',
#        'base_egg_steps', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense',
#        'speed', 'abilities_0', 'abilities_1', 'abilities_2',
#        'abilities_hidden', 'against_normal', 'against_fire', 'against_water',
#        'against_electric', 'against_grass', 'against_ice', 'against_fighting',
#        'against_poison', 'against_ground', 'against_flying',
#        'against_psychict', 'against_bug', 'against_rock', 'against_ghost',
#        'against_dragon', 'against_dark', 'against_steel', 'against_fairy',
#        'is_sublegendary', 'is_legendary', 'is_mythical', 'evochain_0',
#        'evochain_1', 'evochain_2', 'evochain_3', 'evochain_4', 'evochain_5',
#        'evochain_6', 'gigantamax', 'mega_evolution', 'mega_evolution_alt',
#        'description'],
#       dtype='object')
# Index(['gen', 'primary_type', 'secondary_type', 'classification',
#        'percent_male', 'percent_female', 'height_m', 'weight_kg',
#        'capture_rate', 'base_egg_steps', 'hp', 'attack', 'defense',
#        'sp_attack', 'sp_defense', 'speed', 'against_normal', 'against_fire',
#        'against_water', 'against_electric', 'against_grass', 'against_ice',
#        'against_fighting', 'against_poison', 'against_ground',
#        'against_flying', 'against_psychict', 'against_bug', 'against_rock',
#        'against_ghost', 'against_dragon', 'against_dark', 'against_steel',
#        'against_fairy', 'is_sublegendary', 'is_legendary', 'is_mythical',
#        'gigantamax', 'mega_evolution', 'mega_evolution_alt'],
#       dtype='object')

# %%
unique_classes =pokemon_df["classification"].unique()
print("Number of unique classes:", len(unique_classes))
unique_primary_types = pokemon_df["primary_type"].unique()
print("Number of unique primary types:", len(unique_primary_types))
unique_secondary_types = pokemon_df["secondary_type"].unique()
print("Number of unique secondary types:", len(unique_secondary_types))

pokemon_df = pokemon_df.drop(columns=['classification'])
# Out:
# Number of unique classes: 647
# Number of unique primary types: 18
# Number of unique secondary types: 19

# %%
pokemon_df['percent_male'] = pokemon_df['percent_male'].fillna('0')
pokemon_df['percent_female'] = pokemon_df['percent_female'].fillna('0')
pokemon_df.loc[pokemon_df['percent_male'].str.match(r'50\*'), 'percent_male'] = '50'
pokemon_df.loc[pokemon_df['percent_female'].str.match(r'50\*'), 'percent_female'] = '50'

print("Unique values in percent_male:", pokemon_df['percent_male'].unique())
# Out:
# Unique values in percent_male: ['88.14' '50.2' '50' '0' '100' '24.9' '75.49' '88.1' '24.6' '75.4' '11.2']

# %%
pokemon_df['has_mega_evolution'] = (
    pokemon_df['mega_evolution'].notna() | pokemon_df['mega_evolution_alt'].notna()
).astype(int)

pokemon_df['has_gigantamax'] = pokemon_df['gigantamax'].notna().astype(int)

pokemon_df = pokemon_df.drop(columns=['mega_evolution', 'mega_evolution_alt', 'gigantamax'])

# %%
pokemon_df['rarity'] = (
    1 * pokemon_df['is_sublegendary'] +
    2 * pokemon_df['is_legendary'] +
    3 * pokemon_df['is_mythical']
)
pokemon_df = pokemon_df.drop(columns=['is_sublegendary', 'is_legendary', 'is_mythical'])
print(pokemon_df.columns)
# Out:
# Index(['gen', 'primary_type', 'secondary_type', 'percent_male',
#        'percent_female', 'height_m', 'weight_kg', 'capture_rate',
#        'base_egg_steps', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense',
#        'speed', 'against_normal', 'against_fire', 'against_water',
#        'against_electric', 'against_grass', 'against_ice', 'against_fighting',
#        'against_poison', 'against_ground', 'against_flying',
#        'against_psychict', 'against_bug', 'against_rock', 'against_ghost',
#        'against_dragon', 'against_dark', 'against_steel', 'against_fairy',
#        'has_mega_evolution', 'has_gigantamax', 'rarity'],
#       dtype='object')

# %%
type_columns = ['primary_type', 'secondary_type']
gen_map = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'VI': 6, 'VII': 7, 'VIII': 8}
pokemon_df['gen'] = pokemon_df['gen'].map(gen_map)

columns_to_cast = [col for col in pokemon_df.columns if col not in type_columns]

pokemon_df[columns_to_cast] = pokemon_df[columns_to_cast].astype(float)

# %%
print("Primary Types:", unique_primary_types)
print("Secondary Types:", unique_secondary_types)
pokemon_df['secondary_type'] = pokemon_df['secondary_type'].fillna('No secondary type')
unique_secondary_types_clean = pokemon_df['secondary_type'].unique()
print("Secondary Types (clean):", unique_secondary_types_clean)
# Out:
# Primary Types: ['grass' 'fire' 'water' 'bug' 'normal' 'poison' 'electric' 'ground'
#  'fairy' 'fighting' 'psychic' 'rock' 'ghost' 'ice' 'dragon' 'dark' 'steel'
#  'flying']
# Secondary Types: ['poison' nan 'flying' 'dark' 'electric' 'ice' 'ground' 'fairy' 'grass'
#  'fighting' 'psychic' 'steel' 'fire' 'rock' 'water' 'dragon' 'ghost' 'bug'
#  'normal']
# Secondary Types (clean): ['poison' 'No secondary type' 'flying' 'dark' 'electric' 'ice' 'ground'
#  'fairy' 'grass' 'fighting' 'psychic' 'steel' 'fire' 'rock' 'water'
#  'dragon' 'ghost' 'bug' 'normal']

# %%
for col in pokemon_df.columns:
    unique_vals = pokemon_df[col].unique()
    print(f"Column: {col}")
    print(f"Unique values ({len(unique_vals)}): {unique_vals}\n")
# Out:
# Column: gen
# Unique values (8): [1. 2. 3. 4. 5. 6. 7. 8.]
#
# Column: primary_type
# Unique values (18): ['grass' 'fire' 'water' 'bug' 'normal' 'poison' 'electric' 'ground'
#  'fairy' 'fighting' 'psychic' 'rock' 'ghost' 'ice' 'dragon' 'dark' 'steel'
#  'flying']
#
# Column: secondary_type
# Unique values (19): ['poison' 'No secondary type' 'flying' 'dark' 'electric' 'ice' 'ground'
#  'fairy' 'grass' 'fighting' 'psychic' 'steel' 'fire' 'rock' 'water'
#  'dragon' 'ghost' 'bug' 'normal']
#
# Column: percent_male
# Unique values (11): [ 88.14  50.2   50.     0.   100.    24.9   75.49  88.1   24.6   75.4
#   11.2 ]
#
# Column: percent_female
# Unique values (11): [ 11.86  49.8   50.   100.     0.    75.1   24.51  11.9   75.4   24.6
#   88.8 ]
#
# Column: height_m
# Unique values (53): [ 0.7  1.   2.   0.6  1.1  1.7  0.5  1.6  0.3  1.5  1.2  3.5  0.4  0.8
#   1.3  0.9  1.4  0.2  1.9  1.8  8.8  2.2  6.5  2.5  2.1  4.   2.3  9.2
#   5.2  3.8 14.5  2.7  6.2  4.5  7.   2.4  5.4  4.2  3.7  3.2  3.3  0.1
#   2.6  2.8  2.9  3.   5.8  5.   3.9  3.4  5.5  3.6 20. ]
#
# Column: weight_kg
# Unique values (439): [6.900e+00 1.300e+01 1.000e+02 8.500e+00 1.900e+01 9.050e+01 9.000e+00
#  2.250e+01 8.550e+01 2.900e+00 9.900e+00 3.200e+01 3.200e+00 1.000e+01
#  2.950e+01 1.800e+00 3.000e+01 3.950e+01 3.500e+00 1.850e+01 2.000e+00
#  3.800e+01 6.500e+01 6.000e+00 1.200e+01 7.000e+00 2.000e+01 6.000e+01
#  1.950e+01 6.200e+01 7.500e+00 4.000e+01 1.990e+01 5.500e+00 5.500e+01
#  5.400e+00 8.600e+00 1.860e+01 1.250e+01 8.000e-01 3.330e+01 4.200e+00
#  1.960e+01 7.660e+01 2.800e+01 1.550e+02 1.240e+01 5.400e+01 5.650e+01
#  4.800e+01 7.050e+01 1.300e+02 4.000e+00 6.400e+00 1.550e+01 4.550e+01
#  1.050e+02 3.000e+02 9.500e+01 3.600e+01 7.850e+01 1.500e+01 3.920e+01
#  8.520e+01 9.000e+01 1.200e+02 1.325e+02 1.000e-01 4.050e+01 2.100e+02
#  3.240e+01 7.560e+01 6.500e+00 1.040e+01 6.660e+01 2.500e+00 4.500e+01
#  4.980e+01 5.020e+01 6.550e+01 1.000e+00 9.500e+00 1.150e+02 3.460e+01
#  3.500e+01 8.000e+01 8.000e+00 2.500e+01 3.900e+01 3.450e+01 5.450e+01
#  5.600e+01 4.060e+01 4.450e+01 8.840e+01 2.350e+02 2.200e+02 2.900e+01
#  2.450e+01 3.650e+01 1.150e+01 5.900e+01 4.600e+02 5.540e+01 5.260e+01
#  3.300e+00 1.650e+01 1.220e+02 1.580e+01 1.005e+02 7.900e+00 7.950e+01
#  8.880e+01 3.250e+01 2.120e+01 4.080e+01 1.080e+01 3.560e+01 3.350e+01
#  7.500e+01 3.000e+00 1.500e+00 7.800e+00 1.330e+01 6.150e+01 5.800e+00
#  2.850e+01 3.390e+01 5.000e-01 2.650e+01 2.700e+01 2.100e+00 5.000e+00
#  4.150e+01 7.200e+00 1.258e+02 1.400e+01 6.480e+01 4.000e+02 4.870e+01
#  3.900e+00 1.180e+02 2.050e+01 8.800e+00 5.580e+01 1.600e+01 5.050e+01
#  1.520e+02 7.120e+01 5.800e+01 2.100e+01 2.350e+01 2.140e+01 7.550e+01
#  4.680e+01 1.780e+02 1.980e+02 1.870e+02 7.200e+01 2.020e+02 2.160e+02
#  1.990e+02 2.160e+01 5.220e+01 5.200e+01 7.600e+00 8.190e+01 1.360e+01
#  3.700e+01 1.750e+01 3.600e+00 2.840e+01 3.160e+01 2.600e+00 5.960e+01
#  2.300e+00 1.980e+01 6.600e+00 2.020e+01 4.840e+01 1.700e+00 4.500e+00
#  2.400e+01 4.650e+01 1.305e+02 1.200e+00 1.630e+01 8.400e+01 8.640e+01
#  2.538e+02 9.700e+01 1.100e+01 3.260e+01 3.600e+02 1.120e+01 3.150e+01
#  1.520e+01 4.020e+01 1.770e+01 1.030e+01 2.080e+01 3.980e+02 8.040e+01
#  3.060e+01 7.150e+01 1.530e+01 8.200e+01 5.130e+01 7.740e+01 2.060e+01
#  4.030e+01 5.250e+01 1.680e+02 1.540e+02 1.900e+00 2.360e+01 3.280e+01
#  2.150e+01 1.080e+02 2.380e+01 6.040e+01 6.820e+01 7.400e+00 1.620e+02
#  2.200e+01 4.700e+01 1.680e+01 2.565e+02 8.760e+01 1.506e+02 2.260e+01
#  2.340e+01 8.700e+00 4.210e+01 1.105e+02 1.026e+02 9.520e+01 2.025e+02
#  5.500e+02 2.300e+02 1.750e+02 2.050e+02 3.520e+02 9.500e+02 2.065e+02
#  1.100e+00 6.080e+01 1.020e+01 3.100e+02 6.200e+00 5.200e+00 2.300e+01
#  8.450e+01 2.490e+01 2.200e+00 2.550e+01 3.050e+01 4.200e+01 1.450e+01
#  1.025e+02 5.700e+01 1.495e+02 3.400e+00 2.330e+01 3.850e+01 9.300e+00
#  6.300e+00 2.990e+01 2.030e+01 4.400e+00 2.730e+01 4.380e+01 6.000e-01
#  1.920e+01 6.050e+01 2.440e+01 4.950e+01 4.440e+01 1.355e+02 3.400e+01
#  1.800e+02 1.400e+02 2.828e+02 1.286e+02 1.386e+02 6.800e+01 5.150e+01
#  2.590e+01 4.250e+01 2.910e+02 3.400e+02 1.066e+02 2.660e+01 3.000e-01
#  6.830e+02 3.360e+02 4.300e+02 4.200e+02 7.500e+02 8.560e+01 3.100e+00
#  1.400e+00 3.200e+02 8.100e+00 6.300e+01 5.550e+01 1.500e+02 5.900e+00
#  9.460e+01 1.160e+01 4.100e+00 1.470e+01 6.100e+01 1.010e+01 3.750e+01
#  1.050e+01 1.350e+01 2.980e+01 1.800e+01 1.020e+02 2.600e+02 4.040e+01
#  3.100e+01 8.700e+01 1.700e+01 5.100e+01 7.300e+00 5.300e+00 5.850e+01
#  2.005e+02 3.340e+01 9.630e+01 9.290e+01 2.000e+02 1.180e+01 7.650e+01
#  8.100e+01 1.073e+02 8.110e+01 4.400e+01 2.010e+01 2.420e+01 5.700e+00
#  4.100e+01 5.750e+01 9.250e+01 3.300e+01 1.350e+02 1.430e+01 1.880e+01
#  1.100e+02 8.050e+01 3.430e+01 1.055e+02 1.480e+02 7.700e+00 2.530e+01
#  3.550e+01 1.390e+02 9.200e+01 3.300e+02 7.000e+01 1.730e+01 5.000e+01
#  1.600e+02 2.880e+01 4.600e+01 2.500e+02 3.450e+02 3.250e+02 4.850e+01
#  8.250e+01 9.400e+00 1.090e+01 4.240e+01 8.400e+00 8.150e+01 9.000e-01
#  9.100e+01 1.360e+02 5.300e+01 9.600e+01 8.300e+00 3.530e+01 2.600e+01
#  2.700e+02 2.520e+01 2.250e+02 2.800e+00 1.505e+02 7.100e+01 9.950e+01
#  5.050e+02 8.500e+01 2.150e+02 2.030e+02 3.050e+02 1.950e+02 3.660e+01
#  4.300e+00 8.300e+01 1.480e+01 1.420e+01 2.000e-01 9.200e+00 9.200e+02
#  4.800e+00 2.220e+01 6.800e+00 8.200e+00 7.600e+01 8.280e+01 1.205e+02
#  2.120e+02 7.000e-01 1.850e+02 2.970e+01 7.820e+01 9.999e+02 3.336e+02
#  8.880e+02 8.200e+02 8.000e+02 4.520e+01 8.900e+00 4.300e+01 1.155e+02
#  7.800e+01 3.105e+02 4.000e-01 5.100e+00 1.170e+02 5.820e+01 3.800e+00
#  5.200e+02 8.900e+01 6.500e+02 1.900e+02 1.450e+02]
#
# Column: capture_rate
# Unique values (34): [ 45. 255. 120. 127.  90. 190.  75. 235. 150.  25. 170.  50. 200. 100.
#  180.  60. 225.  30.  35.   3.  65.  70. 125. 205. 155. 145. 130. 140.
#   15. 220. 160.  80.  55.  10.]
#
# Column: base_egg_steps
# Unique values (10): [ 5120.  3840.  2560.  6400. 10240.  1280.  8960.  7680. 20480. 30720.]
#
# Column: hp
# Unique values (102): [ 45.  60.  80.  39.  58.  78.  44.  59.  79.  50.  40.  65.  63.  83.
#   30.  55.  35.  75.  70.  90.  46.  61.  81.  95.  38.  73. 115. 140.
#   10.  25.  52. 105.  85. 250.  20. 130.  48. 160.  41.  91. 106. 100.
#  125. 190. 255.  28.  68. 150.  31.   1.  64.  84. 104.  72. 144. 170.
#  110.  43.  66.  86.  99.  76.  53.  37.  77.  67.  97. 111.  49.  71.
#  103.  57. 108. 135.  74.  69. 120. 116.  62.  54.  36.  51. 114. 165.
#  109.  89.  92.  56.  88. 123. 101.  82.  42. 126.  47. 137. 107. 223.
#   98.  93. 122. 200.]
#
# Column: attack
# Unique values (112): [ 49.  62.  82.  52.  64.  84.  48.  63.  83.  30.  20.  45.  35.  25.
#   90.  60.  80.  56.  81.  95.  55.  75. 100.  47.  92.  57.  72. 102.
#   70.  41.  76.  50.  65. 105. 110. 130.  40. 120.  85.  73.   5.  67.
#  125.  10. 115. 134.  46.  38.  58.  33. 160.  51.  71.  91.  43.  78.
#   15.  68.  23. 104. 135. 150.  89. 109.  66.  86. 165.  42.  29.  59.
#   94.  93.  24. 112.  61. 106.  69. 140. 123.  88.  53.  98.  77. 103.
#   27. 117. 108.  44.  87. 147.  74. 124.  97. 129. 107.  36.  22.  54.
#  121. 131. 132. 137. 113. 139. 101. 181. 127. 143. 116.  28. 118. 145.]
#
# Column: defense
# Unique values (107): [ 49.  63.  83.  43.  58.  78.  65.  80. 100.  35.  55.  50.  30.  40.
#   75.  60.  44.  69.  85. 110.  52.  67.  87.  57.  77.  48.  73.  20.
#   45.  70.  25.  95.  15. 115. 130. 180. 160.  90.  53.  79. 120.   5.
#  125. 105.  64.  34.  38.  28.  42. 140. 200. 230.  62.  37.  10.  41.
#   61.  32.  23. 135.  97. 150.  71.  68.  88.  51. 118. 168. 102.  66.
#   84.  47.  86. 116. 108.  72.  56.  76. 145. 106.  39.  59.  99.  89.
#  103. 133.  82.  91. 131. 112. 129. 122.  54.  33. 119. 184. 121.  74.
#  152.  92.  98.  31. 107. 139. 101. 211. 143.]
#
# Column: sp_attack
# Unique values (105): [ 65.  80. 100.  60. 109.  50.  85.  20.  25.  90.  45.  35.  70.  31.
#   61.  40.  55.  75.  95.  81.  30. 110. 105. 120. 135.  58. 115. 130.
#   43.  73. 125.  15.  48. 154.  49.  63.  83.  44.  59.  79.  36.  86.
#   56.  76.  72.  33.  10.  51.  71.  91.  47.  46.  23.  74.  94. 114.
#  150.  78. 104. 111.  42.  29.  62.  87.  57.  92.  54.  64.  41.  24.
#   38.  68.  69. 116. 108.  88.  53.  98.  67. 107.  77.  37. 106. 103.
#  112.  97. 145. 129. 128.  32.  27.  99.  39. 131.  66. 126.  82. 113.
#  137. 127. 173. 151. 102. 134. 136.]
#
# Column: sp_defense
# Unique values (99): [ 65.  80. 100.  50.  85.  64. 105.  20.  25.  35.  70.  31.  61.  54.
#   79.  30.  55.  40.  75.  90.  45.  95.  60. 120.  62. 115. 110.  48.
#  125.  63.  83.  56.  96.  76. 130.  42.  58. 230. 140. 135. 154.  41.
#   52.  82.  23.  43.  73.  53.  71.  87. 107.  33. 200. 150.  44. 101.
#   51.  34.  49.  88. 138. 102.  78.  66.  37.  59.  86. 116. 108.  72.
#   77. 106.  39.  69.  32.  67.  99. 129. 128.  36.  38.  98.  57.  81.
#   89.  46. 123.  94.  92. 113.  47. 142. 132.  91. 131.  68. 114. 103.
#  121.]
#
# Column: speed
# Unique values (117): [ 45.  60.  80.  65. 100.  43.  58.  78.  30.  70.  50.  35.  75.  56.
#   71. 101.  72.  97.  55.  90. 110.  40.  41.  76.  85.  20.  25.  95.
#  120. 115. 105.  15.  42.  67. 150.  87.  63.  68.  93.  81.  48. 130.
#   91.  33.   5.  83.  51.  61. 125. 160.  28.  10.  23.  32.  52.  31.
#   36. 108.  66.  34.  39. 112.  74.  84.  82. 102.  47.  46.  77. 113.
#  106.  64.  24.  29. 116. 114.  88.  69.  92.  57.  98.  22.  44.  59.
#   79. 103. 145. 109.  38. 111.  99.  73. 104. 122.  62. 126.  89.  49.
#  118. 123. 124.  27. 117.  96.  37. 151. 121.  13. 107. 143.  94. 119.
#   26. 136. 142. 138. 200.]
#
# Column: against_normal
# Unique values (4): [1.   0.5  0.   0.25]
#
# Column: against_fire
# Unique values (5): [2.   0.5  1.   4.   0.25]
#
# Column: against_water
# Unique values (5): [0.5  2.   1.   4.   0.25]
#
# Column: against_electric
# Unique values (6): [0.5  1.   2.   0.   4.   0.25]
#
# Column: against_grass
# Unique values (5): [0.25 0.5  2.   1.   4.  ]
#
# Column: against_ice
# Unique values (5): [2.   0.5  1.   0.25 4.  ]
#
# Column: against_fighting
# Unique values (6): [0.5  1.   0.25 2.   0.   4.  ]
#
# Column: against_poison
# Unique values (6): [1.   0.5  0.25 2.   0.   4.  ]
#
# Column: against_ground
# Unique values (6): [1.   2.   0.   0.5  0.25 4.  ]
#
# Column: against_flying
# Unique values (5): [2.   1.   0.5  4.   0.25]
#
# Column: against_psychict
# Unique values (6): [2.   1.   0.5  0.   0.25 4.  ]
#
# Column: against_bug
# Unique values (5): [1.   0.5  0.25 2.   4.  ]
#
# Column: against_rock
# Unique values (5): [1.   2.   4.   0.5  0.25]
#
# Column: against_ghost
# Unique values (5): [1.  0.  2.  0.5 4. ]
#
# Column: against_dragon
# Unique values (4): [1.  0.  0.5 2. ]
#
# Column: against_dark
# Unique values (5): [1.   0.5  2.   0.25 4.  ]
#
# Column: against_steel
# Unique values (5): [1.   0.5  2.   0.25 4.  ]
#
# Column: against_fairy
# Unique values (5): [0.5  1.   2.   0.25 4.  ]
#
# Column: has_mega_evolution
# Unique values (2): [0. 1.]
#
# Column: has_gigantamax
# Unique values (2): [0. 1.]
#
# Column: rarity
# Unique values (4): [0. 1. 2. 3.]
